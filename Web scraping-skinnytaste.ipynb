# %%
pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bs4 import BeautifulSoup
import requests
import csv

# %%
source = requests.get('https://www.skinnytaste.com/').text

soup = BeautifulSoup(source, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# ...

# %%
article = soup.find('div', id='content').article
post_content = article.find('div', class_='post-content')
name = post_content.p.text
image = post_content.h2.img['src']
post_meta = article.find('div', class_='post-title').find('div', class_='post-meta')
post_title = post_meta.find('div', 'recipe-meta')
calories = post_title.find('span', class_='wprm-nutrition-wrapper').find('span', class_='value-calories').text
personal_points = post_title.find('span').text
summary = post_content.p.text
receip_keys = []
for receip_key_span in post_meta.find('div', class_='icons').find_all('span'):
  receip_keys.append(receip_key_span.a.img['alt'])
# Out:
# ['Gluten Free', 'Keto Recipes', 'Kid Friendly', 'Low Carb']
